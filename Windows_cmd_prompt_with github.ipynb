# %% [markdown]
# $\text{Version control : Github}$
#
# $\text{Review written by EG Timerise }$
#
# $\text{Written as a quick reference guide for some of the main functions of Github and windows command prompt.}$
#
# $\text{Mainly for if my computer  crashes , I will have an quick and easy reference guide (although most of this stuff I will/should remember)...anyway...}$

# %% [markdown]
# $\text{First , lets recall some of the commands and methods we can use in cmd for windows}$
#
# $\text{Recall that cmd , really is 'Command prompt' for windows.}$
#
# $\text{There are a various commands that can be used in the windows command prompt, but we will only review a few.}$
#
# $\text{Now, search and open up your windows command prompt.}$
#
# $\text{Then type in the word: help }$
#
# $\text{Then press enter.}$
#
# $\text{You should see a list of possible windows commands}$

# %%
from IPython.core.display import Image
Image(filename=r'C:\Users\dragon\Desktop\command0.png')

# %% [markdown]
# $\text{ Now type the windows command 'cls', to clean up your command prompt.}$

# %%
Image(filename=r'C:\Users\dragon\Desktop\command1.png')

# %% [markdown]
# $\text{To learn more about the various commands, simply type the command followed by /?  , then hit enter}$
#
# $\text{Check the example below , for the 'shift' command.}$

# %%
Image(filename=r'C:\Users\dragon\Desktop\command2.png')

## other interesting command is ipconfig , which shows Internet protocal information

##' SFC \scannow ' = system file check, can be used to repair missing or corrupted system files

## Dir = displays a list of files and subdirectories in a file

## ping= to conduct ping tests

## cd..  = moving out of a folder

## cd filename  = takes you to your sub folder Example  'cd windows' , when you are at 'c:\'

## if you keep using 'cd..' you will find your self at the root file

## also you could use 'cd\' to move to the root file faster

## dir /s  = will list all the files in the d

## hit contorl-c to stop a program in cmd

## md = lets you make a folder just type the name after : Example  'md foldername'

## del = lets you delete a folder, example:  'del foldername'

## notepad = lets you create a notepad document Example : 'notepad documentname'

## rd  = removes file  example  'rd foldername' 

## * be careful where and when you use these commands, can mess up your computer.

## start = lets you open or run the contents of a file

## can switch root files , 'D:' ,'C:' , 'F:' ,ect. 

## robocopy = used for file migration 

## cipher = used for simple file encryptions

## ** Again, watch were you use some of these commands!

# %% [markdown]
# #### installing git  on Windows
#
# $\text{ Go to the following website and download whats needed:}$
#
# $\text{https://git-scm.com/download/win}$
#
# $\text{You can check to see if your upload files work by typing the following into your computers command prompt (for windows computers!).}$
#
# $\text{git --version}$
#
# ###### * note: there is a single space inbetween  't ' and '-'

# %%
Image(filename=r'C:\Users\dragon\Desktop\commands0.png')
## should be the main website for Git

# %% [markdown]
# #### configuring git information
# $\text{Open up the command Prompt on your windows computer.}$
#
# $\text{Type in the following to see the suprisingly short list of commands you will need to learn/review.}$
#
# $\text{git config}$

# %%
Image(filename=r'C:\Users\dragon\Desktop\commands1.png')

# %% [markdown]
# ## setting up username and email
#
# ### $\text{ git config --global user.name fullname}$
#
# $\text{** replace 'fullname' with your name.**}$
#
# $\text{** there is a space between 'g' and '-' **}$
#
# ### $\text{git config --global user.email emailAddress}$
#
# $\text{** replace 'emailAddress' with your desire email address**}$
#
# $\text{** there is a space between 'g' and '-' **}$

# %% [markdown]
# ## Pull request on Github
#
# $\text{First fork the desire repository on github if its not yours.}$
#
# $\text{When you fork a repository from another user, it will show up in your repository area.}$
#
# $\text{Instead of forking someones repository, you could also hit the 'clone or download' button on their repository page (its the huge green button).}$

# %%
Image(filename=r'C:\Users\dragon\Desktop\commands2.png')

# %% [markdown]
# $\text{After copying the address use the 'git clone' command followed by the URL to points to the repository.}$
#
# $\text{** usually the URL is just the current page URL with '.git' added to it.**}$
#
# $\text{git clone https://$%$^$@%(%)#$/randomstuff.git}$
#
# $\text{Check out the example below:}$

# %%
Image(filename=r'C:\Users\dragon\Desktop\commands3.png')

# %% [markdown]
# $\text{Now lets check out our desktop area.}$

# %%
Image(filename=r'C:\Users\dragon\Desktop\commands4.png')

# %% [markdown]
# $\text{Ok, so now we know how to quickly copy files from github from the cmd prompt.}$
#
# ## making new branches on personal computer:
#
# $\text{Usually you will want to create new branches from the master branch, although thats not always the case.}$
#
# $\text{When you make a new branch , make sure you make it clear about what it is.}$
#
# $\text{Note that the new branch will be created from 'statistical-Review' on our desktop.}$
#
# $\text{We will use the following command , 'git branch newbranchname'}$
#
# $\text{Example below:}$
#
# $\text{git branch new1-SR-branch}$

# %%
Image(filename=r'C:\Users\dragon\Desktop\commands5.png')

# %% [markdown]
# $\text{Now we can switch to the new branch we just created.}$
#
# $\text{In our case , its 'new1-SR-branch'}$
#
# $\text{We will use the 'git checkout' command to complete this task.}$
#
# $\text{check out the example below.}$

# %%
Image(filename=r'C:\Users\dragon\Desktop\commands6.png')

# %% [markdown]
# $\text{We could have created and switched to our new branch in one line of code.}$
#
# $\text{With the code below:}$
#
# $\text{git checkout -b new2}$

# %%
Image(filename=r'C:\Users\dragon\Desktop\commands7.png')

# %% [markdown]
# $\text{Anyway... lets switch back to new1-SR-branch}$
#
# $\text{Recall we have to use 'git checkout' command for this}$
#
# $\text{**Also note, if you want to check out the master file , just type the following:}$
#
# $\text{git checkout master }$

# %%
Image(filename=r'C:\Users\dragon\Desktop\commands8.png')

# %% [markdown]
# $\text{Now we can add our take away from our branch file information  (i.e. do some work)}$
#
# $\text{To show this off, we opened the readme file in Statistical review and add some words.}$
#
# $\text{Note that we set everything to the branch file new1-SR-branch before hand.}

# %%
Image(filename=r'C:\Users\dragon\Desktop\commands9.png')

# %% [markdown]
# $\text{ Now lets use the command 'git status'.}$
#
# $\text{Notice  that we cansee that the readme.md file as been modified}$
#
# $\text{So to modify a file on your local computer all you have to do is open it , edit it, then save it.}$
#
# $\text{* Note that git has three levels:}$
#
#
#
# $\text{* 1. working directory}$
#
# $\text{* 2. Staging Area}$
#
# $\text{* 3. git directory repository}$
#
# $\text{we are currently in the working directory level}$

# %%
Image(filename=r'C:\Users\dragon\Desktop\commands11.png')

# %% [markdown]
# $\text{ Now that we have modified our files, we can add them to our local repository.}$
#
# $\text{This can be confusing, since it already looks like it was added visually.}$
#
# $\text{we can use the 'git add -A ' command, wills stage all modifications.  }$
#
# $\text{Thus the Readme.md file will be place at the staging level.}$

# %%
Image(filename=r'C:\Users\dragon\Desktop\commands12.png')

# %%
$\text{Now lets check the status of our Readme.md file}$

$\text{Notes the change in color and the different out put it yields.}$
# Out:
#   File "<ipython-input-16-0dedd0bc4ea6>", line 1
#     $\text{Now lets check the status of our Readme.md file}$
#     ^
# SyntaxError: invalid syntax

# %%
Image(filename=r'C:\Users\dragon\Desktop\commands13.png')

# %% [markdown]
# $\text{This proves that we are in the staging area.}$
#
# $\text{Now we need to commit the file, so that we place it in our local directory repository.}$
#
# $\text{ We will use the 'git commit' command to complete this task.}$
#
# $\text{Check out the example below.}$
#
# $\text {also note that '-m' allows us to add comments with the commit as we move it to our local directory repository.}$

# %%
Image(filename=r'C:\Users\dragon\Desktop\commands14.png')

# %% [markdown]
# ## $\text{Now we need to push our edited file back to github online.}$
#
# $\text{To complete this task, we will use the 'git push' command.}$
#
# $\text{So the code is :}$
#
# $\text{git -push --set-upstream origin new1-SR-branch}$
#
# $\text{from the screen shot below, you will notes that there are now two branches on your github page.}$
#
# $\text{When you push a file, some always has to say yes or no for merging it.}$
#
# $\text{Since its your own file, your going to have to say yes to merging.}$

# %%
Image(filename=r'C:\Users\dragon\Desktop\commands15.png')

# %%
Image(filename=r'C:\Users\dragon\Desktop\commands16.png')

# %%
Image(filename=r'C:\Users\dragon\Desktop\commands16.png')

# %%
Image(filename=r'C:\Users\dragon\Desktop\commands17.png')

# %%
Image(filename=r'C:\Users\dragon\Desktop\commands18.png')

# %%
Image(filename=r'C:\Users\dragon\Desktop\commands19.png')

# %% [markdown]
# $\text{Next lets cover how to initially make a github repository based off work you have already created on your computer.}$
#
# $\text{Will update section later, thanks for reading thus far (if anyone besides me actually looks at this).}$
